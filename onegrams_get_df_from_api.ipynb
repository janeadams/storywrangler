# %%
import pandas as pd

# %%
import requests

# %%
r = requests.get("http://hydra.uvm.edu:3001/api/onegrams/christmas")

# %%
data = r.json()

# %%
df  = pd.DataFrame(data)

# %%
df
# Out:
#                            _id   counts   rank                      time  \
# 0     5c440ec97ad7ce043465a89f    13658   2339  2019-01-08T00:00:00.000Z
# 1     5c440edc7ad7ce04346e52ad    12427   2576  2019-01-09T00:00:00.000Z
# 2     5c440eef7ad7ce0434771fac     7507   4344  2019-01-12T00:00:00.000Z
# 3     5c440f037ad7ce04347fd735     7671   4314  2019-01-13T00:00:00.000Z
# 4     5c440f167ad7ce043488c3c9     6804   4767  2019-01-14T00:00:00.000Z
# 5     5c440f2a7ad7ce043491957a     6484   5375  2019-01-15T00:00:00.000Z
# 6     5c440f3e7ad7ce04349ab733    97273    300  2018-12-09T00:00:00.000Z
# 7     5c440f527ad7ce0434a35531   107624    281  2018-12-10T00:00:00.000Z
# 8     5c440f667ad7ce0434abd5c3   121156    254  2018-12-11T00:00:00.000Z
# 9     5c440f7b7ad7ce0434b45a04   122123    276  2018-12-12T00:00:00.000Z
# 10    5c440f907ad7ce0434bd373f   130232    229  2018-12-13T00:00:00.000Z
# 11    5c440fa47ad7ce0434c5a09a   131745    255  2018-12-14T00:00:00.000Z
# ...
